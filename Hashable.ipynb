# %% [markdown]
# ## Hashable-объекты

# %%
class User:
    def __init__(self, name: str, surname: str, is_active: bool = False):
        self.name = name
        self.surname = surname
        self.is_active = is_active

# %%
petr = User(name='User', surname='Petrov')
print(u.name)
petr.name = 'Petr'
print(u.name)
# Out:
# User
# Petr

# %%
data = {petr: 100}

# %%
print(data)
# Out:
# {<__main__.User object at 0x1187b58b0>: 100}

# %%
petr.name = 'Petya'
print(petr.name)
# Out:
# Petya

# %%
print(petr)
# Out:
# <__main__.User object at 0x1187b58b0>

# %%
petr.__hash__()
# Out:
# 294106507

# %% [markdown]
# **Ответьте на вопросы**:
#   - можно ли использовать объекты класса User в качестве ключа в словаре?
#   - являются ли объекты класса User хэшируемыми?
#   - являются ли объекты класса User изменяемыми?

# %%
data = (1, 2, 3)
hash(data)
# Out:
# 529344067295497451

# %%
hash([1, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 hash([1, 2, 3])
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# #### Являются ли объекты класса User hashable?

# %%
petr = User(name='Petr', surname='Petrov')
petr_clone = User(name='Petr', surname='Petrov')

user_age_map = {
    petr: 20, 
    petr_clone: 26,
}
print(user_age_map)

print(hash(petr_clone))
print(hash(petr))
# Out:
# {<__main__.User object at 0x1187fa780>: 20, <__main__.User object at 0x1187fa7e0>: 26}
# 294124158
# 294124152

# %%
user_age_map[petr]
# Out:
# 20

# %%
user_age_map[petr_clone]
# Out:
# 26

# %%
p

# %% [markdown]
# Видим, что объекты являются хэшируемыми, но есть нюанс..

# %%
x = User(name='Petr', surname='Petrov')
user_age_map[x]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 user_age_map[User(name='Petr', surname='Petrov')]
#
# KeyError: <__main__.User object at 0x1187b5340>

# %%
user_age_map1 = {
    'Petr Petrov': 20
}
user_age_map1['Petr Petrov']
# Out:
# 20

# %%
ages = {
    User(name='Petr', surname='Petrov'): 20, 
    User(name='Petr', surname='Ivanov'): 26,
}

# %%
ages = {
    'Petr Petrov': 20, 
    'Petr Ivanov': 26, 
}

# %%
name = 'Petr'
surname = 'Petrov'

ages['Petr Petrov']
# Out:
# 20

# %%
hash('Petr Petrov') == hash('Petr Petrov')
# Out:
# True

# %% [markdown]
# Ожидаемое поведение аналогично строкам, например:

# %%
user_age_map1 = {
    'Petr Petrov': 20,
    'Petr Petrov': 26
}

# %%
user_age_map1
# Out:
# {'Petr Petrov': 26}

# %%
user_age_map1['Petr Petrov']
# Out:
# 26

# %%
hash('Petr Petrov')
# Out:
# 8397874054901821506

# %%
hash('Petr Petrov')
# Out:
# 8397874054901821506

# %%
petr == petr_clone
# Out:
# False

# %% [markdown]
# Т.е. hash-значения объектов равны

# %%
'Petr Petrov' == 'Petr Petrov'
# Out:
# True

# %%
1 + 1 == 2
# Out:
# True

# %% [markdown]
# А вот hash-значения объектов класса User отличаются

# %%
User(name='Petr', surname='Petrov') == User(name='Petr', surname='Petrov')
# Out:
# False

# %% [markdown]
# #### Как реализовать hashable-объекты правильно? Модель данных!

# %%
class User:
    def __init__(self, name: str, surname: str, is_active: bool = False):
        self.__name = name
        self.__surname = surname
        self.__is_active = is_active

    def __hash__(self) -> int:
        return hash((self.__name, self.__surname))

    def __eq__(self, other) -> bool:
        return self.__name == other.__name and self.__surname == other.__surname

# %%
User(name='Petr', surname='Petrov') == User(name='Petr', surname='Petrov')
# Out:
# False

# %%
petr = User(name='Petr', surname='Petrov')
petr_clone = User(name='Petr', surname='Petrov')
hash(petr), hash(petr_clone), hash(User(name='Petr', surname='Petrov'))
# Out:
# (8560102211492810366, 8560102211492810366, 8560102211492810366)

# %%
petr = User(name='Petr', surname='Petrov')
petr_clone = User(name='Petr', surname='Petrov')

user_age_map = {
    petr: 20, 
    petr_clone: 26,
}
print(user_age_map)
user_age_map[User(name='Petr', surname='Petrov')]
# Out:
# {<__main__.User object at 0x11a214650>: 26}
# 26

# %%
print(f'{hash(petr)} =? {hash(petr_clone)}')
# Out:
# 5870677628674637673 =? 5870677628674637673

# %%
hash(('Petr', 'Petrov'))
# Out:
# 5870677628674637673

# %%
hash(petr) == hash(petr_clone) == hash(User(name='Petr', surname='Petrov'))
# Out:
# True

# %%
petr == petr_clone == User(name='Petr', surname='Petrov')
# Out:
# False

# %%
bucket = [
    (('Petr', 'Ivanov'), 22), 
    (('Petr', 'Petrov'), 26), 
    (('Petr', 'Abramov'), 75)
]
key = ('Petr', 'Petrov')

for value, age in bucket:
    if key == value: # __eq__
        print(age)
# Out:
# 26

# %%
bucket = [
    (petr, 22), 
    (petr_clone, 26), 
]
key = User(name='Petr', surname='Petrov')

for value, age in bucket:
    if key == value:
        print(age)
# Out:
# 22
# 26

# %%
petr = User(name='Petr', surname='Petrov')
ivan = User(name='Ivan', surname='Ivanov')
print(f'hash before = {hash(petr)}')
user_age_map = {
    petr: 20, 
    ivan: 26,
}

petr.name = 'Fedr'
print(f'hash after = {hash(petr)}')

print(user_age_map)
user_age_map[petr]
# Out:
# hash before = 5870677628674637673
# hash after = 5870677628674637673
# {<__main__.User object at 0x119339370>: 20, <__main__.User object at 0x11933b5f0>: 26}
# 20

# %% [markdown]
# #### Еще пример

# %%
class Point:
    def __init__(self, x: int, y: int):
        self.__x = x
        self.__y = y
    
    def __eq__(self, other):
        return self.__x == other.__x and self.__y == other.__y
    
    def __hash__(self):
        return hash((self.__x, self.__y))
    
    def __repr__(self) -> str:  # Point(x=1, y=2)
        return f'Point(x={self.__x}, y={self.__y})'

    def __str__(self) -> str:  # (1, 2)
        return f'({self.__x}, {self.__y})'
    
    @property
    def x(self):
        return self.__x
    
    @property
    def y(self):
        return self.__y


point_a = Point(1, 1)
point_b = Point(1, 1)
print('x =', point_a.x)
points = {point_a, point_b, Point(0, 0), point_a}
print(points)

print(hash(point_a))
print(hash(point_b))

print(point_a)
print(repr(point_a))
# Out:
# x = 1
# {Point(x=1, y=1), Point(x=0, y=0)}
# 8389048192121911274
# 8389048192121911274
# (1, 1)
# Point(x=1, y=1)

# %%
point_a.x = 10
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 point_a.x = 10
#
# File <string>:4, in __setattr__(self, name, value)
#
# FrozenInstanceError: cannot assign to field 'x'

# %%
# point_a.__dict__['sd'] = 1
point_a.sd = 120
point_a.__dict__
# Out:
# {'_Point__x': 1, '_Point__y': 1, 'sd': 120}

# %% [markdown]
# #### Есть ли способ проще? Dataclass

# %%
from dataclasses import dataclass


@dataclass(frozen=True)
class Point:
    x: int
    y: int


point_a = Point(1, 1)
point_b = Point(1, 1)
{point_a, point_b, Point(0, 0), point_a}
# Out:
# {Point(x=0, y=0), Point(x=1, y=1)}

# %%
point_a == point_b
# Out:
# False

# %%
user_age_map = {
    'petr': 20, 
    'petr': 26,
}
print(user_age_map)
# Out:
# {'petr': 26}

# %%
@dataclass(slots=True)
class Point:
    x: int
    y: int

# %%
point_a = Point(1, 1)
point_a.x = 2
print(point_a)
# Out:
# <__main__.Point object at 0x1194a6290>

# %%
class Point:
    def __init__(self, x: int, y: int):
        self.x = x
        self.y = y

point_a = Point(1, 1)
point_a.z = 3
point_a.__dict__
# Out:
# {'x': 1, 'y': 1, 'z': 3}

# %%
class Point:
    __slots__ = ['x', 'y']
    def __init__(self, x: int, y: int):
        self.x = x
        self.y = y

# %%
point_a = Point(1, 1)
point_a.z = 3
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Cell In[92], line 2
#       1 point_a = Point(1, 1)
# ----> 2 point_a.z = 3
#
# File <string>:4, in __setattr__(self, name, value)
#
# FrozenInstanceError: cannot assign to field 'z'

# %%
point_a == point_b # ->
point_a.__eq__(point_b)
# Out:
# True

# %% [markdown]
# ### P.S. Модель данных в Python
# https://docs.python.org/3/reference/datamodel.html

# %%
class FriendCollection:
    def __init__(self, my_friends: list[str], wife_friends: list[str]):
        self._my_friends = my_friends
        self._wife_friends = wife_friends
        self._extra = []
    
    @property
    def _friends(self):
        return self._my_friends + self._wife_friends + self._extra

    def __str__(self):
        return ', '.join(self._friends)
    
    def __len__(self):
        return len(self._friends)

    def __iter__(self):
        return iter(self._friends)

    def __iadd__(self, friends):
        self._extra += friends
        return self

    # def __setattr__(self):
    #     raise NotImplemented()

friends = FriendCollection(['Петя', 'Вася'], ['Катя', 'Наташа'])
print(f'Friends count: {len(friends)}')
print(f'All friends: {friends}')
friends += ['Маша', 'Саша']

for friend in friends:
    print(friend)
# Out:
# Friends count: 4
# All friends: Петя, Вася, Катя, Наташа
# Петя
# Вася
# Катя
# Наташа
# Маша
# Саша
