# %% [markdown]
# ## GIT. Основы

# %% [markdown]
# ### 🤔 Зачем нужен Git?
#
# **Знакомая ситуация?**
#
# ```
# 📁 Мой проект/
# ├── курсовая.docx
# ├── курсовая_v2.docx
# ├── курсовая_финал.docx
# ├── курсовая_финал_ИСПРАВЛЕННАЯ.docx
# ├── курсовая_финал_ИСПРАВЛЕННАЯ_2.docx
# └── курсовая_СДАВАТЬ_ЭТУ!!!.docx
# ```
#
# **Проблемы без системы контроля версий:**
# - 😰 Не помнишь, что менял в каждой версии
# - 😱 Случайно удалил важный код и не можешь вернуть
# - 🤯 Работаешь в команде — и все правят один файл одновременно
# - 😵 Нужно откатиться к "той рабочей версии недельной давности"
#
# **Git решает все эти проблемы!**

# %% [markdown]
# ### 📖 Что такое Git?
#
# **Git** — это **система контроля версий** (Version Control System, VCS).
#
# Простыми словами: Git запоминает **каждое изменение** в файлах и позволяет:
#
# | Возможность | Что это значит |
# |-------------|----------------|
# | 📸 Сохранять "снимки" проекта | Можно вернуться к любой версии |
# | 🔄 Отменять изменения | Накосячил? Откатись назад! |
# | 👥 Работать в команде | Каждый работает в своей копии, потом всё сливается |
# | 🌿 Создавать ветки | Экспериментируй, не ломая основной код |
# | 📝 Видеть историю | Кто, когда и что изменил |
#
# > 💡 **Git ≠ GitHub!**
# > Git — это программа на компьютере.
# > GitHub — это сайт для хранения Git-репозиториев в облаке.

# %% [markdown]
# ### 🧱 Основные понятия
#
# #### 📦 Репозиторий (Repository)
# Папка проекта + скрытая папка `.git`, где Git хранит всю историю.
#
# ```
# 📁 my-project/
# ├── 📁 .git/          ← Здесь Git хранит всю магию
# ├── 📄 main.py
# ├── 📄 utils.py
# └── 📄 README.md
# ```
#
# #### 📸 Коммит (Commit)
# **Снимок** состояния проекта в определённый момент времени.
#
# ```
# Коммит = Что изменилось + Кто изменил + Когда + Сообщение
#
# Пример:
# ──────────────────────────────────────────
# 📸 Коммит #a1b2c3d
# 👤 Автор: Иван Петров
# 📅 Дата: 2026-01-16 14:30
# 💬 Сообщение: "Добавил функцию расчёта скидки"
# ──────────────────────────────────────────
# ```
#
# #### 🌿 Ветка (Branch)
# **Независимая линия разработки.** Можно экспериментировать, не трогая основной код.
#
# ```
# main:        ●───●───●───●───●
#                      \
# feature:              ●───●───●
# ```

# %% [markdown]
# ### ⚡ Основные команды Git
#
# #### 🚀 Начало работы
# ```bash
# git init                    # Создать новый репозиторий
# git clone <url>             # Скачать существующий репозиторий
# ```
#
# #### 📝 Ежедневная работа
# ```bash
# git status                  # Что изменилось?
# git add <файл>              # Подготовить файл к коммиту
# git add .                   # Подготовить ВСЕ изменения
# git commit -m "сообщение"   # Сохранить снимок
# ```
#
# #### 🔄 Работа с удалённым репозиторием
# ```bash
# git push                    # Отправить изменения на сервер
# git pull                    # Получить изменения с сервера
# ```
#
# #### 🌿 Работа с ветками
# ```bash
# git branch                  # Список веток
# git branch <имя>            # Создать ветку
# git checkout <имя>          # Переключиться на ветку
# git merge <имя>             # Слить ветку в текущую
# ```
#
# #### 🔍 Просмотр истории
# ```bash
# git log                     # История коммитов
# git log --oneline           # Компактная история
# git diff                    # Что изменилось (ещё не закоммичено)
# ```

# %% [markdown]
# ### 🔄 Как Git отслеживает изменения
#
# Git использует **3 области** для отслеживания файлов:
#
# ```
# ┌─────────────────┐    git add     ┌─────────────────┐   git commit   ┌─────────────────┐
# │                 │  ──────────▶   │                 │  ──────────▶   │                 │
# │  Working Dir    │                │  Staging Area   │                │   Repository    │
# │  (Рабочая папка)│                │  (Индекс)       │                │   (История)     │
# │                 │                │                 │                │                 │
# │  Твои файлы     │                │  Что войдёт в   │                │  Сохранённые    │
# │  прямо сейчас   │                │  следующий      │                │  снимки         │
# │                 │                │  коммит         │                │                 │
# └─────────────────┘                └─────────────────┘                └─────────────────┘
# ```
#
# **Типичный рабочий процесс:**
#
# ```
# 1. Редактируем файлы           → Working Directory
# 2. git add файл.py              → Staging Area
# 3. git commit -m "Описание"     → Repository
# 4. git push                     → GitHub (удалённый сервер)
# ```

# %% [markdown]
# ### 🎯 Практический пример: первый репозиторий
#
# ```bash
# # 1. Создаём папку проекта
# mkdir my-first-repo
# cd my-first-repo
#
# # 2. Инициализируем Git
# git init
# # Вывод: Initialized empty Git repository in .../my-first-repo/.git/
#
# # 3. Создаём файл
# echo "print('Hello, Git!')" > main.py
#
# # 4. Проверяем статус
# git status
# # Вывод: Untracked files: main.py (Git видит файл, но не отслеживает)
#
# # 5. Добавляем файл в индекс
# git add main.py
#
# # 6. Делаем первый коммит
# git commit -m "Добавить приветствие"
# # Вывод: [main (root-commit) a1b2c3d] Добавить приветствие
#
# # 7. Смотрим историю
# git log --oneline
# # Вывод: a1b2c3d Добавил приветствие
#
# # 🎉 Готово! Первый коммит сделан!
# ```

# %% [markdown]
# ### 💡 Советы для начинающих
#
# #### ✅ Хорошие практики
# - **Коммить часто** — маленькие изменения легче понять и откатить
# - **Пиши понятные сообщения** — "Исправить баг в расчёте скидки", а не "fix"
# - **Один коммит = одна логическая задача** — не мешай всё в кучу
#
# #### ❌ Частые ошибки
#
# | Ошибка | Как исправить |
# |--------|---------------|
# | Забыл `git add` перед коммитом | `git add .` затем `git commit` |
# | Опечатка в сообщении коммита | `git commit --amend -m "Новое сообщение"` |
# | Добавил лишний файл | `git reset HEAD файл` (до коммита) |
# | Хочу отменить последний коммит | `git reset --soft HEAD~1` |
#
# #### 📛 Что НЕ стоит коммитить
# ```
# ❌ Пароли и ключи API
# ❌ node_modules/, venv/ (зависимости)
# ❌ .pyc, __pycache__/ (скомпилированные файлы)
# ❌ .env (переменные окружения)
# ❌ Большие бинарные файлы (видео, архивы)
# ```
#
# > 💡 Используй файл `.gitignore` чтобы Git игнорировал ненужные файлы!

# %% [markdown]
# ---
# ## 📚 Дополнительные материалы

# %% [markdown]
# Основной источник: [git-scm.com](https://git-scm.com/book/ru/v2/%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5-%D0%9E-%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC%D0%B5-%D0%BA%D0%BE%D0%BD%D1%82%D1%80%D0%BE%D0%BB%D1%8F-%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D0%B9)
#
# Основные команды [ссылка](https://git-scm.com/book/ru/v2/%D0%9F%D1%80%D0%B8%D0%BB%D0%BE%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-C%3A-%D0%9A%D0%BE%D0%BC%D0%B0%D0%BD%D0%B4%D1%8B-Git-%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D0%BD%D1%8B%D0%B5-%D0%BA%D0%BE%D0%BC%D0%B0%D0%BD%D0%B4%D1%8B):
# 1. `git clone` -- клонирование репозитория
# 2. `git add` -- добавляет содержимое рабочего каталога в индекс (staging area) для последующего коммита.
# 3. `git commit -m ` -- берёт все данные, добавленные в индекс с помощью git add, и сохраняет их слепок во внутренней базе данных, а затем сдвигает указатель текущей ветки на этот слепок.
# 4. `git push` -- используется для установления связи с удалённым репозиторием, вычисления локальных изменений отсутствующих в нём, и собственно их передачи в вышеупомянутый репозиторий.
# 5. `git pull` -- Git вначале забирает изменения из указанного удалённого репозитория, а затем пытается слить их с текущей веткой.
# 6. `git checkout` -- используется для переключения веток и выгрузки их содержимого в рабочий каталог.
# 7. `git branch` -- это своего рода "менеджер веток". Она умеет перечислять ваши ветки, создавать новые, удалять и переименовывать их.
# 8. `git status` -- оказывает состояния файлов в рабочем каталоге и индексе: какие файлы изменены, но не добавлены в индекс; какие ожидают коммита в индексе. Вдобавок к этому выводятся подсказки о том, как изменить состояние файлов.
# 9. `git log` -- используется для просмотра истории коммитов, начиная с самого свежего и уходя к истокам проекта. По умолчанию, она показывает лишь историю текущей ветки, но может быть настроена на вывод истории других, даже нескольких сразу, веток.
# 10. `git stash` -- используется для временного сохранения всех незафиксированных изменений с целью очистки рабочего каталога без необходимости фиксировать незавершённую работу в текущей ветке.
# 11. `git stash pop` -- позволяет вернуть все незафиксированные изменения, которые были ранее сохранены

# %% [markdown]
# ### Github. Быстрый старт
# 1. Регистрация: https://github.com/signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2F&source=header-home
# 2. [Настройка ssh](https://git-scm.com/book/ru/v2/Git-%D0%BD%D0%B0-%D1%81%D0%B5%D1%80%D0%B2%D0%B5%D1%80%D0%B5-%D0%93%D0%B5%D0%BD%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D1%8F-%D0%BE%D1%82%D0%BA%D1%80%D1%8B%D1%82%D0%BE%D0%B3%D0%BE-SSH-%D0%BA%D0%BB%D1%8E%D1%87%D0%B0) + дополнительная ссылка [github doc](https://docs.github.com/ru/authentication/connecting-to-github-with-ssh/generating-a-new-ssh-key-and-adding-it-to-the-ssh-agent)
# 3. Создать репозиторий
# 4. Клонировать репозиторий на локальный компьютер
# 5. Внесение изменений (git commit && git push)

# %% [markdown]
# #### Простейшая модель ветвления
# <img src="https://habrastorage.org/r/w1560/storage/4bf7e68c/49e29c35/3a01bd6b/782a1be3.png">

# %% [markdown]
# Ссылка: https://habr.com/ru/post/106912/
